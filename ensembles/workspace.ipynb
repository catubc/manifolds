# %%
import matplotlib
# %matplotlib tk
# %autosave 180
# %load_ext autoreload
# %autoreload 2

import nest_asyncio
# %config Completer.use_jedi = False

#
import matplotlib.pyplot as plt
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

import scipy
import numpy as np
import pandas as pd
import os
os.chdir('/home/cat/code/manifolds')

from calcium import calcium
from wheel import wheel
from visualize import visualize
from tqdm import trange



import numpy as np
import scipy
from scipy.io import loadmat
# Out:
# Autosaving every 180 seconds
# <style>.container { width:100% !important; }</style>

# %%
#######################################################
#######################################################
#######################################################
# #data = loadmat('/media/cat/4TBSSD/donato/HEX5_K5_medium__T1800s_dT500ms_cT1s_sKInf_eF10.0mHz_eM6_nS0/HEX5_K5_medium__T1800s_dT500ms_cT1s_sKInf_eF10.0mHz_eM6_nS0_CALCIUM-FLUORESCENCE.mat')
# data = loadmat('/media/cat/4TBSSD/donato/HEX5_K5_medium__T1800s_dT500ms_cT1s_sKInf_eF10.0mHz_eM6_nS0/HEX5_K5_medium__T1800s_dT500ms_cT1s_sKInf_eF10.0mHz_eM6_nS0_CALCIUM-FLUORESCENCE_rawF.mat')
# print (len(data))

# print (data.keys())
# # print (data['activity_raster'].shape)
# # print (data['activity_raster_threshold'].shape)
# # print (data['activity_raster_peaks'].shape)


root_dir = '/media/cat/4TB/donato/'
animal_id = "DON-006084"
session_id = "20210520"

#/suite2p/plane0/pca_upphase_random_True.npy'""

F_upphase = np.load(os.path.join()'/media/cat/4TBSSD/donato/binarized_traces/F_upphase.npy').T
print (F_upphase.shape)
# Out:
# (55740, 531)

# %%
#######################################################
#######################################################
#######################################################
# 
width = 15
F_binned = []
for k in range(0,F_upphase.shape[0],width):
    temp = F_upphase[k:k+width].sum(0)
    #temp = F_python[k:k+width].sum(0)
    #print (temp.shape)
    F_binned.append(temp)
    
F_binned = np.vstack(F_binned)
print (F_binned.shape)
np.save('/media/cat/4TBSSD/donato/upphase/F_upphase_binned_sum.npy',
       F_binned)
# Out:
# (3716, 531)

# %%
print (F_binned[0])
# Out:
# [ 1.41728369e+03 -1.41626587e+02  1.04655579e+02 -1.92033691e+01
#  -2.09565430e+01 -9.45617676e+01  2.42745667e+02 -2.79636230e+01
#  -9.63734131e+01 -1.02593689e+02 -2.34323853e+02 -1.70457153e+01
#   3.24729614e+01  3.17140503e+01 -1.27152100e+01 -7.76028442e+01
#  -7.91329956e+01  1.23033447e+01 -1.10070679e+02 -3.59093201e+02
#   4.00636658e+02  1.21006531e+02  1.24868164e+01  2.76110352e+02
#   7.70012207e+01 -2.01898193e+01 -6.28910522e+01  1.56092285e+02
#  -4.58433228e+01 -3.82372437e+01 -5.09165649e+01  1.92822266e+01
#   1.44313721e+02  1.07317688e+02 -1.02319214e+02 -1.91114746e+02
#   2.02979187e+02  1.37847107e+02  9.82998657e+01 -1.20902283e+02
#  -1.55184692e+02 -2.01943359e+01 -2.06618652e+01  1.91932983e+01
#  -2.17150879e+02  4.53334351e+01 -3.98943481e+01  1.03243896e+02
#   9.20072632e+01 -7.99949951e+01  1.07454834e+01 -1.66143799e+02
#  -6.00145874e+01 -8.35097046e+01  6.59899292e+01 -7.43700562e+01
# ...

# %%
######################################################
######################################################
######################################################

data = loadmat('/media/cat/4TBSSD/donato/HEX5_K5_medium__T1800s_dT500ms_cT1s_sKInf_eF10.0mHz_eM6_nS0/HEX5_K5_medium__T1800s_dT500ms_cT1s_sKInf_eF10.0mHz_eM6_nS0_ACTIVITY-RASTER.mat')
print (len(data))

print (data.keys())
print (data['activity_raster'].shape)
print (data['activity_raster_threshold'].shape)
print (data['activity_raster_peaks'].shape)
# Out:
# 6
# dict_keys(['__header__', '__version__', '__globals__', 'activity_raster', 'activity_raster_threshold', 'activity_raster_peaks'])
# (55740, 616)
# (1, 1)
# (3540, 1)

# %%
######################################################
######################################################
######################################################
peaks = data['activity_raster_peaks']
print (peaks)

sums = data['activity_raster'].sum(axis=1)
print (sums.shape)

t=np.arange(sums.shape[0])/30.
fig=plt.figure()
plt.plot(t, sums)
plt.plot(t[peaks-1], sums[peaks-1])

plt.show()
# Out:
# [[    2]
#  [    4]
#  [    7]
#  ...
#  [55732]
#  [55737]
#  [55740]]
# (55740,)

# %%
data = loadmat('/media/cat/4TBSSD/donato/HEX5_K5_medium__T1800s_dT500ms_cT1s_sKInf_eF10.0mHz_eM6_nS0/HEX5_K5_medium__T1800s_dT500ms_cT1s_sKInf_eF10.0mHz_eM6_nS0_ICA-ASSEMBLIES.mat')
print (len(data))

print (data.keys())
print (data['mp_assembly_vectors'].shape)
print (data['mp_assemblies'].shape)
ks_alpha = data['ks_alpha']
print (ks_alpha)
#print (data['activity_raster_peaks'].shape)
# Out:
# 8
# dict_keys(['__header__', '__version__', '__globals__', 'cs_assembly_vectors', 'cs_assemblies', 'ks_alpha', 'mp_assembly_vectors', 'mp_assemblies'])
# (1, 79)
# (79, 1)
# [[1.e-10]]

# %%
vecs = data['mp_assembly_vectors'].squeeze()
print (vecs[0].shape)
# Out:
# (616, 1)

# %%
ens_cs = data['cs_assemblies']
print (ens_cs[1])
ens_mp = data['mp_assemblies']
print (ens_mp[1])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-ab80f47178ed> in <module>
#       1 ens = data['cs_assemblies']
# ----> 2 print (ens[2])
#
# IndexError: index 2 is out of bounds for axis 0 with size 2
